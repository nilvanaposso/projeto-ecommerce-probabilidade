# %%
File
 → Save and Export Notebook As
 → Executable Script (.py)
# Out:
#   Cell In[3], line 2
#     → Save and Export Notebook As
#     ^
# IndentationError: unexpected indent

# %%
File → Save and Export Notebook As → Executable Script (.py)
# Out:
#   Cell In[2], line 1
#     File → Save and Export Notebook As → Executable Script (.py)
#          ^
# SyntaxError: invalid character '→' (U+2192)
